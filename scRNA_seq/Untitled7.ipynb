# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/scRNA-tools/scRNA-tools/master/database/tools.tsv",sep="\t")

# %%
df.head()
# Out:
#        Tool      Platform                                       Code  \
# 0    acorde             R        https://github.com/ConesaLab/acorde
# 1    ACTINN        Python        https://github.com/mafeiyang/ACTINN
# 2    ACTION  C++/R/MATLAB              http://compbio.mit.edu/ACTION
# 3  ACTIONet         R/C++  https://github.com/shmohammadi86/ACTIONet
# 4    ACTIVA        Python         https://github.com/SindiLab/ACTIVA
#
#                                          Description           License  \
# 0  Isoform co-usage networks from single-cell RNA...           GPL-3.0
# 1  ACTINN (Automated Cell Type Identification usi...           GPL-3.0
# 2  ACTION infers the functional identity of cells...               NaN
# 3  Robust multi-resolution analysis of single-cel...  GPL-2.0-or-later
# 4  Realistic scRNAseq Generation with Automatic C...               MIT
#
#         Added     Updated
# 0  2021-05-14  2021-05-14
# 1  2019-02-01  2021-06-28
# 2  2018-04-23  2021-06-28
# ...

# %%
df = df.sort_values("Added")

# %%
df
# Out:
#           Tool  Platform                                               Code  \
# 58        BPSC         R                   https://github.com/nghiavtr/BPSC
# 739      scLVM  R/Python                     https://github.com/PMBio/scLVM
# 684      SCell    MATLAB                   https://github.com/diazlab/SCell
# 901      SinQC  R/Python                http://www.morgridge.net/SinQC.html
# 507      Ouija         R           https://github.com/kieranrcampbell/ouija
# ..         ...       ...                                                ...
# 677  scDiffCom         R           https://github.com/CyrilLagger/scDiffCom
# 715      scHPL    Python             https://github.com/lcmmichielsen/scHPL
# 818      SCSit  C/Python                https://github.com/shang-qian/SCSit
# 330   graph-sc    Python  https://github.com/ciortanmadalina/graph-sc-pa...
# 734  Sciviewer    Python             https://github.com/colabobio/sciviewer
#
# ...

# %%
df[df.Platform=="R"].to_csv("tools.csv")
