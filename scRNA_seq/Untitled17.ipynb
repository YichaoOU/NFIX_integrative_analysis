# %%
import pandas as pd

# %%
df = pd.read_csv("random_sampling_1000.csv")

# %%
df.head()
# Out:
#                 X1            X2            X3        X4            X5  \
# init  2.997641e-03  4.815123e-02  5.954190e-02  0.197959  2.133315e-02
# X     3.032694e-04  7.949079e-07  7.826860e-03  0.008278  1.091085e-26
# X.1   5.427592e-02  7.447222e-08  2.644224e-10  0.012035  7.330532e-03
# X.2   3.386180e-14  8.648522e-06  3.550353e-04  0.000017  1.703909e-04
# X.3   4.610165e-07  7.975287e-11  1.905067e-06  0.000090  7.051366e-09
#
#                 X6            X7        X8            X9           X10  ...  \
# init  6.930545e-03  2.411480e-03  0.000328  1.543086e-01  1.880072e-02  ...
# X     8.143818e-07  2.330658e-02  0.035918  5.160359e-02  3.482701e-02  ...
# X.1   1.755060e-02  1.108825e-01  0.007246  6.407039e-05  2.311221e-04  ...
# X.2   2.736784e-04  1.075346e-07  0.000108  4.184413e-04  8.635335e-05  ...
# X.3   3.044561e-08  3.437841e-05  0.003605  6.879066e-08  8.548717e-15  ...
#
#               X992          X993          X994          X995          X996  \
# ...

# %%
df = df.set_index("rownames")

# %%
df.shape
# Out:
# (11, 1000)

# %%
df.head()
# Out:
#                     X1            X2            X3        X4            X5  \
# rownames
# Ery       2.997641e-03  4.815123e-02  5.954190e-02  0.197959  2.133315e-02
# CMP       3.032694e-04  7.949079e-07  7.826860e-03  0.008278  1.091085e-26
# ST-HSC.1  5.427592e-02  7.447222e-08  2.644224e-10  0.012035  7.330532e-03
# LT-HSC.1  3.386180e-14  8.648522e-06  3.550353e-04  0.000017  1.703909e-04
# GMP       4.610165e-07  7.975287e-11  1.905067e-06  0.000090  7.051366e-09
#
#                     X6            X7        X8            X9           X10  \
# rownames
# Ery       6.930545e-03  2.411480e-03  0.000328  1.543086e-01  1.880072e-02
# CMP       8.143818e-07  2.330658e-02  0.035918  5.160359e-02  3.482701e-02
# ST-HSC.1  1.755060e-02  1.108825e-01  0.007246  6.407039e-05  2.311221e-04
# LT-HSC.1  2.736784e-04  1.075346e-07  0.000108  4.184413e-04  8.635335e-05
# GMP       3.044561e-08  3.437841e-05  0.003605  6.879066e-08  8.548717e-15
#
# ...

# %%
df.mean(axis=1)
# Out:
# rownames
# Ery         0.028986
# CMP         0.024008
# ST-HSC.1    0.009852
# LT-HSC.1    0.001247
# GMP         0.001157
# MKP         0.003540
# ERP         0.010358
# LT-HSC.2    0.003884
# MEP         0.000028
# ST-HSC.2    0.019689
# MPP         0.000915
# dtype: float64

# %%
BTW,
